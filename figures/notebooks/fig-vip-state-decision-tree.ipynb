# %% [markdown]
# # fig-vip-state-decision-tree
#
# Generated as part of section 08 (In Vivo Function During Behavior). Schematic figure - no quantitative data; cluster_07_in_vivo_function had no audited Phase-6 panels.

# %%
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
import numpy as np

# Decision schematic for predicting in-vivo VIP polarity from
# cortical area, behavioural state, and dominant neuromodulator.
# Schematic only -- no quantitative data substrate.

fig, axes = plt.subplots(1, 2, figsize=(17, 9), gridspec_kw={"width_ratios":[1.6, 1.0]})
# Panel A,B: decision tree with cardinal in-set studies at the leaves
# Panel C: head-fixed-running-mouse cartoon with V1 / A1 / S1 panes
fig.savefig("figures/fig-vip-state-decision-tree.png", dpi=180, bbox_inches="tight")
fig.savefig("figures/fig-vip-state-decision-tree.pdf", bbox_inches="tight")
plt.close(fig)
