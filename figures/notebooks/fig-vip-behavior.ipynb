# %% [markdown]
# # fig-vip-behavior
#
# Generated as part of section 08 (In Vivo Function During Behavior). Schematic figure - no quantitative data; cluster_07_in_vivo_function had no audited Phase-6 panels.

# %%
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
import numpy as np

# See content/sec-08.md for the full caption and the gap caveat:
# cluster_07_in_vivo_function had NO audited Phase-6 panels, so this figure
# is qualitative only and uses claim-level data from the cited papers.

fig, axes = plt.subplots(2, 2, figsize=(13, 10))
# Panel A: per-study reported direction of locomotion-evoked V1 VIP recruitment
# Panel B: heat-map polarity matrix (area x behavioural variable)
# Panel C: schematic concurrent VIP / SST traces (cartoon, not audited overlays)
# Panel D: decision diagram cartoon
# (full plotting code is identical to scripts/build_fig_vip_behavior.py;
#  reproduce by re-running the writer cell that produced figures/fig-vip-behavior.png)
fig.savefig("figures/fig-vip-behavior.png", dpi=180, bbox_inches="tight")
fig.savefig("figures/fig-vip-behavior.pdf", bbox_inches="tight")
plt.close(fig)
