# %% [markdown]
# # Reproducibility notebook — `fig-cge-fraction-cross-species` (REDESIGNED)
#
# **Status:** methods-only schematic. **No quantitative cross-paper comparison was achievable** for this figure: the underlying datasets use non-matched subclass definitions, reference areas and lineage definitions.
#
# **Why redesigned:** Phase 6 audit of `cluster_14_cge_lineage_context` found 0 audited panels — there is insufficient method-matched data across mouse / marmoset / macaque / human to draw a quantitative stacked comparison.
#
# **What is shown:**
# - Panel A: two study-specific anchors (Miyoshi 2010 mouse fate map, ~30% CGE; Hodge 2019 human MTG snRNA-seq, 50% ADARB2+ / 44% LHX6+).
# - Panel B: subclass partitioning **placeholder** (hashed bars) across Mouse / Marmoset / Macaque / Human MTG, with explicit 'NO AUDITED CROSS-PAPER DATA' overlay.
# - Panel C: methodological-variable inventory (lineage definition, reference area, subclass resolution, primate-specific lineages).
#
# **Caveat in caption:** No quantitative cross-paper comparison was achievable; the figure is methods-only / schematic, with the directional claim (mouse < primate CGE-class fraction) supported but the precise gap dependent on measurement modality.

# %%
import matplotlib.pyplot as plt
import numpy as np
import matplotlib.patches as mpatches

# Anchor values used in Panel A:
panel_a = {
    'Mouse cortex (Miyoshi 2010, fate map)': {'CGE': 30, 'MGE': 70, 'Other': 0},
    'Human MTG (Hodge 2019, snRNA-seq)':     {'CGE': 50, 'MGE': 44, 'Other': 6},
}
for k,v in panel_a.items():
    print(k, v)

# Panel B is a deliberate placeholder — non-matched subclass definitions across Tasic 2018, Krienen 2023, Schmitz 2022, Hodge 2019.
print('Methods-only schematic — see fig-cge-fraction-cross-species.png/.pdf.')
