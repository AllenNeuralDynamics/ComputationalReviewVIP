# %% [markdown]
# # fig-vip-effect-size-comparison
#
# Cross-study effect-size comparison for VIP-mediated cortical inhibition.

# %%
# Notebook stub for fig-vip-effect-size-comparison.png
# The figure PNG was assembled from cross-study evidence in the curated literature corpus.
# See the gate JSON file for provenance and source sentences.
print('See gate JSON for provenance.')
